# %%
import pandas as pd
import numpy as np

# %%
data0=pd.read_excel('goc.xls', skiprows=range(1),skipfooter=4)

# %%
data0.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Toplam\nTotal',
#        'Türk\nvatandaşları\nTurkish citizens',
#        'Yabancı uyruklular\nForeign nationals', 'Unnamed: 5',
#        'Toplam\nTotal.1', 'Türk\nvatandaşları\nTurkish citizens.1',
#        'Yabancı uyruklular\nForeign nationals.1', 'Unnamed: 9',
#        'Toplam\nTotal.2', 'Türk\nvatandaşları\nTurkish citizens.2',
#        'Yabancı uyruklular\nForeign nationals.2', 'Unnamed: 13'],
#       dtype='object')

# %%
data0.rename(columns={'Unnamed: 0':'Years', 'Unnamed: 1':'Provinces', 'Toplam\nTotal':'Total',
                    'Türk\nvatandaşları\nTurkish citizens':'TurkishCitizens','Yabancı uyruklular\nForeign nationals':'ForeignCitizens',
                    'Toplam\nTotal.1':'TotalImmigrants','Türk\nvatandaşları\nTurkish citizens.1':'TurkishImmigrants','Yabancı uyruklular\nForeign nationals.1':'ForeignImmigrants',
                    'Toplam\nTotal.2':'TotalEmigrants','Türk\nvatandaşları\nTurkish citizens.2':'TurkishEmigrants','Yabancı uyruklular\nForeign nationals.2':'ForeignEmigrants',
                    'Unnamed: 13':'NetMigration'}, inplace=True)

# %%
data0
# Out:
#       Years       Provinces     Total  TurkishCitizens  ForeignCitizens  \
# 0    2021.0    Toplam-Total  84680273         82888237          1792036
# 1       NaN           Adana   2263373          2247474            15899
# 2       NaN        Adıyaman    632148           630523             1625
# 3       NaN  Afyonkarahisar    744179           731760            12419
# 4       NaN            Ağrı    524644           523527             1117
# ..      ...             ...       ...              ...              ...
# 487     NaN          Yalova    241665           230538            11127
# 488     NaN         Karabük    242347           237620             4727
# 489     NaN           Kilis    130825           130290              535
# 490     NaN        Osmaniye    522175           521561              614
# 491     NaN           Düzce    370371           366744             3627
#
#      Unnamed: 5  TotalImmigrants  TurkishImmigrants  ForeignImmigrants  \
# ...

# %%
data0.drop(['Unnamed: 5','Unnamed: 9'], axis=1, inplace=True)

# %%
data=data0.copy()

# %%
data.set_index('Provinces', inplace=True)

# %%
data.fillna(0)
# Out:
#                  Years     Total  TurkishCitizens  ForeignCitizens  \
# Provinces
# Toplam-Total    2021.0  84680273         82888237          1792036
# Adana              0.0   2263373          2247474            15899
# Adıyaman           0.0    632148           630523             1625
# Afyonkarahisar     0.0    744179           731760            12419
# Ağrı               0.0    524644           523527             1117
# ...                ...       ...              ...              ...
# Yalova             0.0    241665           230538            11127
# Karabük            0.0    242347           237620             4727
# Kilis              0.0    130825           130290              535
# Osmaniye           0.0    522175           521561              614
# Düzce              0.0    370371           366744             3627
#
#                 TotalImmigrants  TurkishImmigrants  ForeignImmigrants  \
# Provinces
# ...

# %%
data['Years']=data['Years'].to_list()
new_years=data['Years'].fillna(0).astype('int32')
new_years=new_years.mask(new_years==0, '')

# %%
data['Years']=new_years

# %%
data
# Out:
#                Years     Total  TurkishCitizens  ForeignCitizens  \
# Provinces
# Toplam-Total    2021  84680273         82888237          1792036
# Adana                  2263373          2247474            15899
# Adıyaman                632148           630523             1625
# Afyonkarahisar          744179           731760            12419
# Ağrı                    524644           523527             1117
# ...              ...       ...              ...              ...
# Yalova                  241665           230538            11127
# Karabük                 242347           237620             4727
# Kilis                   130825           130290              535
# Osmaniye                522175           521561              614
# Düzce                   370371           366744             3627
#
#                 TotalImmigrants  TurkishImmigrants  ForeignImmigrants  \
# Provinces
# Toplam-Total             739364             124269             615095
# ...

# %%
data.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492 entries, Toplam-Total to Düzce
# Columns: 11 entries, Years to NetMigration
# dtypes: int64(10), object(1)
# memory usage: 46.1+ KB

# %%
data[['Years', 'TotalImmigrants', 'TotalEmigrants', 'NetMigration']]
# Out:
#                Years  TotalImmigrants  TotalEmigrants  NetMigration
# Provinces
# Toplam-Total    2021           739364          287651        451713
# Adana                            6126            4218          1908
# Adıyaman                          880             997          -117
# Afyonkarahisar                   6081            1605          4476
# Ağrı                              593             584             9
# ...              ...              ...             ...           ...
# Yalova                           5484            1374          4110
# Karabük                          2075             418          1657
# Kilis                             156             111            45
# Osmaniye                          659             377           282
# Düzce                            2214             525          1689
#
# [492 rows x 4 columns]

# %%
data[data.index == 'Adana']
# Out:
#           Years    Total  TurkishCitizens  ForeignCitizens  TotalImmigrants  \
# Provinces
# Adana            2263373          2247474            15899             6126
# Adana            2258718          2244748            13970             4490
# Adana            2237940          2223904            14036             6163
# Adana            2220125          2208316            11809             6894
# Adana            2216475          2207079             9396             6827
# Adana            2201670          2192471             9199             4697
#
#            TurkishImmigrants  ForeignImmigrants  TotalEmigrants  \
# Provinces
# Adana                   2013               4113            4218
# Adana                   1863               2627            3810
# Adana                   1979               4184            3511
# Adana                   2304               4590            4275
# Adana                   2367               4460            4129
# ...

# %%
data.iloc[1]
# Out:
# Years
# Total                2263373
# TurkishCitizens      2247474
# ForeignCitizens        15899
# TotalImmigrants         6126
# TurkishImmigrants       2013
# ForeignImmigrants       4113
# TotalEmigrants          4218
# TurkishEmigrants        2210
# ForeignEmigrants        2008
# NetMigration            1908
# Name: Adana, dtype: object

# %%
data.loc['Adana', ['TotalImmigrants', 'TotalEmigrants', 'NetMigration']]
# Out:
#            TotalImmigrants  TotalEmigrants  NetMigration
# Provinces
# Adana                 6126            4218          1908
# Adana                 4490            3810           680
# Adana                 6163            3511          2652
# Adana                 6894            4275          2619
# Adana                 6827            4129          2698
# Adana                 4697            4092           605

# %%
data.columns = list(map(str, data.columns))
[print (type(x)) for x in data.columns.values]
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
condition = data['Years'] == 2021
print(condition)
# Out:
# Provinces
# Toplam-Total       True
# Adana             False
# Adıyaman          False
# Afyonkarahisar    False
# Ağrı              False
#                   ...
# Yalova            False
# Karabük           False
# Kilis             False
# Osmaniye          False
# Düzce             False
# Name: Years, Length: 492, dtype: bool

# %%
data[condition]
# Out:
#              Years     Total  TurkishCitizens  ForeignCitizens  \
# Provinces
# Toplam-Total  2021  84680273         82888237          1792036
#
#               TotalImmigrants  TurkishImmigrants  ForeignImmigrants  \
# Provinces
# Toplam-Total           739364             124269             615095
#
#               TotalEmigrants  TurkishEmigrants  ForeignEmigrants  NetMigration
# Provinces
# Toplam-Total          287651            103613            184038        451713

# %%
data1=data[(data['Years']==2021) | (data['Years']==2020) | (data['Years']==2019) | (data['Years']==2018) | (data['Years']==2017) | (data['Years']==2016)]

# %%
data1.index=data1['Years']

# %%
data1.drop(['Years'],axis=1)
# Out:
#           Total  TurkishCitizens  ForeignCitizens  TotalImmigrants  \
# Years
# 2021   84680273         82888237          1792036           739364
# 2020   83614362         82280952          1333410           340845
# 2019   83154997         81623817          1531180           677042
# 2018   82003882         80792848          1211034           577457
# 2017   80810525         79891464           919061           466333
# 2016   79814871         78998461           816410           380921
#
#        TurkishImmigrants  ForeignImmigrants  TotalEmigrants  TurkishEmigrants  \
# Years
# 2021              124269             615095          287651            103613
# 2020               98349             242496          420463             77810
# 2019               98554             578488          330289             84863
# 2018              110567             466890          323918            136740
# 2017              101772             364561          253640            113326
# ...

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
print('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.5.2

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Plots

# %%
data1.index = data1.index.map(int)
data1['NetMigration'].plot(kind='line')

plt.title('Net Migration To Turkey')
plt.ylabel('Net Migrants')
plt.xlabel('Years')

plt.text(2019,100000, 'Corona Epidemic Period')

plt.show()

# %%
def see_province(prov):
    prov.index = range(2016,2022)
    prov.plot(kind='line',figsize=(20, 10))

    plt.title('Migration Movements')
    plt.ylabel('Changes')
    plt.xlabel('Years')

    plt.show()

# %%
Adana=data.loc['Adana', ['TotalImmigrants', 'TotalEmigrants', 'NetMigration']][::-1]

# %%
Adana
# Out:
#            TotalImmigrants  TotalEmigrants  NetMigration
# Provinces
# Adana                 4697            4092           605
# Adana                 6827            4129          2698
# Adana                 6894            4275          2619
# Adana                 6163            3511          2652
# Adana                 4490            3810           680
# Adana                 6126            4218          1908

# %%
see_province(Adana)

# %%
İstanbul=data.loc['İstanbul', ['TotalImmigrants', 'TotalEmigrants', 'NetMigration']][::-1]

# %%
İstanbul
# Out:
#            TotalImmigrants  TotalEmigrants  NetMigration
# Provinces
# İstanbul            106957           57955         49002
# İstanbul            166044           75849         90195
# İstanbul            201957          113430         88527
# İstanbul            306455          140223        166232
# İstanbul            116229          200211        -83982
# İstanbul            353141          101350        251791

# %%
see_province(İstanbul)

# %%
Ankara=data.loc['Ankara', ['TotalImmigrants', 'TotalEmigrants', 'NetMigration']][::-1]

# %%
Ankara
# Out:
#            TotalImmigrants  TotalEmigrants  NetMigration
# Provinces
# Ankara               33143           14852         18291
# Ankara               46475           27379         19096
# Ankara               71337           28410         42927
# Ankara               62616           28656         33960
# Ankara               28278           39971        -11693
# Ankara               49793           34208         15585

# %%
see_province(Ankara)

# %% [markdown]
# # Plot.Area

# %%
data2=data0.copy()

# %%
data2=data2.drop(['Years'],axis=1)

# %%
data2.index=data2['Provinces']

# %%
data2.drop(['Provinces'],axis=1)
# Out:
#                    Total  TurkishCitizens  ForeignCitizens  TotalImmigrants  \
# Provinces
# Toplam-Total    84680273         82888237          1792036           739364
# Adana            2263373          2247474            15899             6126
# Adıyaman          632148           630523             1625              880
# Afyonkarahisar    744179           731760            12419             6081
# Ağrı              524644           523527             1117              593
# ...                  ...              ...              ...              ...
# Yalova            241665           230538            11127             5484
# Karabük           242347           237620             4727             2075
# Kilis             130825           130290              535              156
# Osmaniye          522175           521561              614              659
# Düzce             370371           366744             3627             2214
#
# ...

# %%
data_area=data2.loc['Toplam-Total',['TotalImmigrants', 'TurkishImmigrants','ForeignImmigrants']][::-1]

# %%
data_area
# Out:
#               TotalImmigrants  TurkishImmigrants  ForeignImmigrants
# Provinces
# Toplam-Total           380921             107052             273869
# Toplam-Total           466333             101772             364561
# Toplam-Total           577457             110567             466890
# Toplam-Total           677042              98554             578488
# Toplam-Total           340845              98349             242496
# Toplam-Total           739364             124269             615095

# %%
data_area.index = range(2016,2022)
data_area.plot(kind='area',
             stacked=False,
             figsize=(20, 10))

plt.title('Immigration Trend of Turkey')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
data_area2=data2.loc['Toplam-Total',['TotalEmigrants', 'TurkishEmigrants','ForeignEmigrants']][::-1]

# %%
data_area2
# Out:
#               TotalEmigrants  TurkishEmigrants  ForeignEmigrants
# Provinces
# Toplam-Total          177960             69326            108634
# Toplam-Total          253640            113326            140314
# Toplam-Total          323918            136740            187178
# Toplam-Total          330289             84863            245426
# Toplam-Total          420463             77810            342653
# Toplam-Total          287651            103613            184038

# %%
data_area2.index = range(2016,2022)
data_area2.plot(kind='area',
             stacked=False,
             figsize=(20, 10))

plt.title('Emigration Trend of Turkey')
plt.ylabel('Number of Emigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# # Bar Chart

# %%
data2=data2.loc['Toplam-Total',['Total']]
data2=data2[::-1]
data2.index=range(2016,2022)

# %%
data2
# Out:
#          Total
# 2016  79814871
# 2017  80810525
# 2018  82003882
# 2019  83154997
# 2020  83614362
# 2021  84680273

# %%
data2.plot(kind='bar', figsize=(10, 6), rot=90)

plt.xlabel('Year')
plt.ylabel('Number of Total Populations')
plt.title('2016-2021 Population Chart')

# Annotate arrow
plt.annotate('',  # s: str. will leave it blank for no text
             xy=(5, 85000000),  # place head of the arrow at point (year 2012 , pop 70)
             xytext=(0, 80000000),  # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',  # will use the coordinate system of the object being annotated
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
             )
plt.annotate('Increase in Population',  # text to display
             xy=(1.5, 83000000),  # start the text at at point (year 2008 , pop 30)
             rotation=2,  # based on trial and error to match the arrow
             va='bottom',  # want the text to be vertically 'bottom' aligned
             ha='left',  # want the text to be horizontally 'left' algned.
             )


plt.show()

# %% [markdown]
# # Pie.Charts

# %%
data4=data.copy()

# %%
data4= data4.groupby('Provinces', axis=0).sum()

# %%
data4.index
# Out:
# Index(['Adana', 'Adıyaman', 'Afyonkarahisar', 'Aksaray', 'Amasya', 'Ankara',
#        'Antalya', 'Ardahan', 'Artvin', 'Aydın', 'Ağrı', 'Balıkesir', 'Bartın',
#        'Batman', 'Bayburt', 'Bilecik', 'Bingöl', 'Bitlis', 'Bolu', 'Burdur',
#        'Bursa', 'Denizli', 'Diyarbakır', 'Düzce', 'Edirne', 'Elazığ',
#        'Erzincan', 'Erzurum', 'Eskişehir', 'Gaziantep', 'Giresun', 'Gümüşhane',
#        'Hakkari', 'Hatay', 'Isparta', 'Iğdır', 'Kahramanmaraş', 'Karabük',
#        'Karaman', 'Kars', 'Kastamonu', 'Kayseri', 'Kilis', 'Kocaeli', 'Konya',
#        'Kütahya', 'Kırklareli', 'Kırıkkale', 'Kırşehir', 'Malatya', 'Manisa',
#        'Mardin', 'Mersin', 'Muğla', 'Muş', 'Nevşehir', 'Niğde', 'Ordu',
#        'Osmaniye', 'Rize', 'Sakarya', 'Samsun', 'Siirt', 'Sinop', 'Sivas',
#        'Tekirdağ', 'Tokat', 'Toplam-Total', 'Trabzon', 'Tunceli', 'Uşak',
#        'Van', 'Yalova', 'Yozgat', 'Zonguldak', 'Çanakkale', 'Çankırı', 'Çorum',
#        'İstanbul', 'İzmir', 'Şanlıurfa', 'Şırnak'],
# ...

# %%
data4=data4.drop(['Toplam-Total'],axis=0)

# %%
data4=data4.sort_values(['Total'])

# %%
data_pie=data4.tail(6)

# %%
data_pie
# Out:
#               Total  TurkishCitizens  ForeignCitizens  TotalImmigrants  \
# Provinces
# Adana      13398301         13323992            74309            35197
# Antalya    14799147         14271485           527662           209223
# Bursa      18138491         17882508           255983           101426
# İzmir      26011475         25831325           180150            76896
# Ankara     33345252         32547456           797796           291642
# İstanbul   91723690         88927221          2796469          1250783
#
#            TurkishImmigrants  ForeignImmigrants  TotalEmigrants  \
# Provinces
# Adana                  12858              22339           24035
# Antalya                20904             188319          108198
# Bursa                  14877              86549           51456
# İzmir                  30070              46826           64683
# Ankara                 45483             246159          173476
# ...

# %%
colors_list = ['orange', 'yellow', 'green', 'lightskyblue', 'grey', 'pink']
explode_list = [0, 0, 0, 0, 0, 0.1] # ratio for each continent with which to offset each wedge.

data_pie['NetMigration'].plot(kind='pie',
                       figsize=(15, 6),
                       autopct='%1.1f%%', 
                       startangle=90,    
                       shadow=True,       
                       labels=None,         # turn off labels on pie chart
                       pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                       colors=colors_list,  # add custom colors
                       explode=explode_list # 'explode' lowest 3 continents
                       )

# scale the title up by 12% to match pctdistance
plt.title('Total Net Migration  [2016 - 2021]', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=data_pie.index, loc='upper left') 

plt.show()

# %% [markdown]
# # Box.Polts

# %%
data5=data.copy()

# %%
data5=data5.loc['Sakarya',['Total']][::-1]
years = list(map(str, range(2016, 2022)))
data5.index=years

# %%
data5
# Out:
#         Total
# 2016   976948
# 2017   990214
# 2018  1010700
# 2019  1029650
# 2020  1042649
# 2021  1060876

# %%
data5.plot(kind='box', figsize=(8, 6))

plt.title('Box Plot of Sakarya Total Population From 2016 - 2021')
plt.ylabel('Number of Populations')

plt.show()

# %%
fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**

# Subplot 1: Box plot
data5.plot(kind='box', color='blue', vert=False, figsize=(20, 6), ax=ax0) # add to subplot 1
ax0.set_title('Box Plots of Sakarya Total Population From 2016 - 2021')
ax0.set_xlabel('Number of Populations')

# Subplot 2: Line plot
data5.plot(kind='line', figsize=(20, 6), ax=ax1) # add to subplot 2
ax1.set_title ('Line Plots of Sakarya Total Population From 2016 - 2021')
ax1.set_ylabel('Number of Populations')
ax1.set_xlabel('Years')

plt.show()

# %% [markdown]
# # Scatter.Graph

# %%
data6=data.copy()

# %%
data6=data6.loc['Toplam-Total',['Years','Total','NetMigration']][::-1]

# %%
x = data6['Years'].astype('int32')      # year on x-axis
y = data6['NetMigration']     # total on y-axis

# %%
fit = np.polyfit(x, y, deg=1)
fit
# Out:
# array([ 1.31440286e+04, -2.62998815e+07])

# %%
data6.plot(kind='scatter', x='Years', y='NetMigration', figsize=(10, 6), color='black')

plt.title('Net Migration to Turkey from 2016 - 2021')
plt.xlabel('Year')
plt.ylabel('Number of Net Migration')

# plot line of best fit
plt.plot(x, fit[0] * x + fit[1], color='red') # recall that x is the Years
plt.annotate('y={0:.0f} x + {1:.0f}'.format(fit[0], fit[1]), xy=(2000, 150000))

plt.show()

# print out the line of best fit
'NetMigrations = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1])
# Out:
# 'NetMigrations = 13144 * Year + -26299882'

# %% [markdown]
# # Bubble.Plots

# %%
data7=data.copy()
data7=data7.loc['Toplam-Total',['Years','Total','NetMigration']][::-1]

# %%
normal_ntmig=(data7['NetMigration'] - data7['NetMigration'].min()) / (data7['NetMigration'].max() - data7['NetMigration'].min())
normal_pop=(data7['Total'] - data7['Total'].min()) / (data7['Total'].max() - data7['Total'].min())

# %%
# Brazil
ax0 = data7.plot(kind='scatter',
                    x='Years',
                    y='NetMigration',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s=normal_ntmig * 1000 + 10,  # pass in weights 
                    xlim=(2015, 2022)
                    )

# Argentina
ax1 = data7.plot(kind='scatter',
                    x='Years',
                    y='Total',
                    alpha=0.5,
                    color="blue",
                    s=normal_pop * 1000 + 10,
                    ax=ax0
                    )

ax0.set_title('Total Population and Net Migrations Scatter Graph')
ax0.legend(['Net Migration', 'Total Population'], loc='center left', fontsize='x-large')
plt.show()

# %% [markdown]
# # Waffle.Charts

# %%
data8=data.copy()

# %%
data8= data8.groupby('Provinces', axis=0).sum()

# %%
data8=data8.drop(['Toplam-Total'],axis=0)
data8=data8.sort_values(['TotalImmigrants']).tail(6)
total_values=data8['TotalImmigrants'].sum()
category_proportions = data8['TotalImmigrants'] / total_values

# %%
category_proportions
# Out:
# Provinces
# Mersin      0.033861
# İzmir       0.038494
# Bursa       0.050774
# Antalya     0.104737
# Ankara      0.145995
# İstanbul    0.626139
# Name: TotalImmigrants, dtype: float64

# %%
width = 40 # width of chart
height = 10 # height of chart

total_num_tiles = width * height # total number of tiles

print(f'Total number of tiles is {total_num_tiles}.')
# Out:
# Total number of tiles is 400.

# %%
# compute the number of tiles for each category
tiles_per_category = (category_proportions * total_num_tiles).round().astype(int)

# print out number of tiles per category
pd.DataFrame({"Number of tiles": tiles_per_category})
# Out:
#            Number of tiles
# Provinces
# Mersin                  14
# İzmir                   15
# Bursa                   20
# Antalya                 42
# Ankara                  58
# İstanbul               250

# %%
waffle_chart = np.zeros((height, width), dtype = np.uint)

# define indices to loop through waffle chart
category_index = 0
tile_index = 0

# populate the waffle chart
for col in range(width):
    for row in range(height):
        tile_index += 1

        # if the number of tiles populated for the current category is equal to its corresponding allocated tiles...
        if tile_index > sum(tiles_per_category[0:category_index]):
            # ...proceed to the next category
            category_index += 1       
            
        # set the class value to an integer, which increases with class
        waffle_chart[row, col] = category_index
        
print ('Waffle chart populated!')
# Out:
# Waffle chart populated!

# %%
waffle_chart.shape
# Out:
# (10, 40)

# %%
fig = plt.figure()

# use matshow to display the waffle chart
colormap = plt.cm.coolwarm
plt.matshow(waffle_chart, cmap=colormap)
plt.colorbar()
plt.show()

# %%
# instantiate a new figure object
fig = plt.figure()

# use matshow to display the waffle chart
colormap = plt.cm.coolwarm
plt.matshow(waffle_chart, cmap=colormap)
plt.colorbar()

# get the axis
ax = plt.gca()

# set minor ticks
ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
# add gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

plt.xticks([])
plt.yticks([])
plt.show()

# %%
# instantiate a new figure object
fig = plt.figure()

# use matshow to display the waffle chart
colormap = plt.cm.coolwarm
plt.matshow(waffle_chart, cmap=colormap)
plt.colorbar()

# get the axis
ax = plt.gca()

# set minor ticks
ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
# add gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

plt.xticks([])
plt.yticks([])

# compute cumulative sum of individual categories to match color schemes between chart and legend
values_cumsum = np.cumsum(data8['TotalImmigrants'])
total_values = values_cumsum[len(values_cumsum) - 1]

# create legend
legend_handles = []
for i, category in enumerate(data8.index.values):
    label_str = category + ' (' + str(data8['TotalImmigrants'][i]) + ')'
    color_val = colormap(float(values_cumsum[i])/total_values)
    legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

# add legend to chart
plt.legend(handles=legend_handles,
           loc='lower center', 
           ncol=len(data8.index.values),
           bbox_to_anchor=(0., -0.2, 0.95, .1)
          )
plt.show()

# %%
def create_waffle_chart(categories, values, height, width, colormap, value_sign=''):

    # compute the proportion of each category with respect to the total
    total_values = sum(values)
    category_proportions = [(float(value) / total_values) for value in values]

    # compute the total number of tiles
    total_num_tiles = width * height # total number of tiles
    print ('Total number of tiles is', total_num_tiles)
    
    # compute the number of tiles for each catagory
    tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

    # print out number of tiles per category
    for i, tiles in enumerate(tiles_per_category):
        print (data8.index.values[i] + ': ' + str(tiles))
    
    # initialize the waffle chart as an empty matrix
    waffle_chart = np.zeros((height, width))

    # define indices to loop through waffle chart
    category_index = 0
    tile_index = 0

    # populate the waffle chart
    for col in range(width):
        for row in range(height):
            tile_index += 1

            # if the number of tiles populated for the current category 
            # is equal to its corresponding allocated tiles...
            if tile_index > sum(tiles_per_category[0:category_index]):
                # ...proceed to the next category
                category_index += 1       
            
            # set the class value to an integer, which increases with class
            waffle_chart[row, col] = category_index
    
    # instantiate a new figure object
    fig = plt.figure()

    # use matshow to display the waffle chart
    colormap = plt.cm.coolwarm
    plt.matshow(waffle_chart, cmap=colormap)
    plt.colorbar()

    # get the axis
    ax = plt.gca()

    # set minor ticks
    ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
    ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
    # add dridlines based on minor ticks
    ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

    plt.xticks([])
    plt.yticks([])

    # compute cumulative sum of individual categories to match color schemes between chart and legend
    values_cumsum = np.cumsum(values)
    total_values = values_cumsum[len(values_cumsum) - 1]

    # create legend
    legend_handles = []
    for i, category in enumerate(categories):
        if value_sign == '%':
            label_str = category + ' (' + str(values[i]) + value_sign + ')'
        else:
            label_str = category + ' (' + value_sign + str(values[i]) + ')'
            
        color_val = colormap(float(values_cumsum[i])/total_values)
        legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

    # add legend to chart
    plt.legend(
        handles=legend_handles,
        loc='lower center', 
        ncol=len(categories),
        bbox_to_anchor=(0., -0.2, 0.95, .1)
    )
    plt.show()

# %%
width = 40 # width of chart
height = 10 # height of chart

categories = data8.index.values # categories
values = data8['TotalImmigrants'] # correponding values of categories

colormap = plt.cm.coolwarm # color map class

# %%
create_waffle_chart(categories, values, height, width, colormap)
# Out:
# Total number of tiles is 400
# Mersin: 14
# İzmir: 15
# Bursa: 20
# Antalya: 42
# Ankara: 58
# İstanbul: 250

# %% [markdown]
# # Regression.Plots

# %%
import seaborn as sns

# %%
data9=data.copy()

# %%
data9=data9.loc['Toplam-Total',['Total','TotalImmigrants']][::-1]
data9.index=range(2016,2022)

# %%
data9
# Out:
#          Total  TotalImmigrants
# 2016  79814871           380921
# 2017  80810525           466333
# 2018  82003882           577457
# 2019  83154997           677042
# 2020  83614362           340845
# 2021  84680273           739364

# %%
plt.figure(figsize=(13, 5))

sns.set(font_scale=1.5)
sns.set_style('whitegrid')

ax = sns.regplot(x='TotalImmigrants', y='Total', data=data9, color='black', marker='*', scatter_kws={'s': 200})
ax.set(xlabel='Total Immigrants', ylabel='Total Populations')
ax.set_title('The Effects of Total Immigrants on Total Populations')
plt.show()
